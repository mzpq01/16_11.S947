# %%
import json
import time
import threading

from datetime import datetime
from twython import Twython

from twitter_key import t_key, t_secret

# %%
# Assigns the keys to the variables
APP_KEY = t_key
APP_SECRET = t_secret

# Setup a Lat Lon
latlong = [42.3598, -71.0921]

''' Fetches tweets with a given query at a given lat-long.'''
def get_tweets( latlong=None ):
    # Creates a Twithon object with the given keys
    twitter = Twython( APP_KEY, APP_SECRET )
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = twitter.search( geocode=','.join([ str(x) for x in latlong ]) + ',2km', result_type='recent', count=10000)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']
print get_tweets( latlong )
# Out:
# [{u'contributors': None, u'truncated': False, u'text': u'#hubspot with the boy @ HubSpot https://t.co/a7nZ8muO6l', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 704791263103463425L, u'favorite_count': 0, u'source': u'<a href="http://instagram.com" rel="nofollow">Instagram</a>', u'retweeted': False, u'coordinates': {u'type': u'Point', u'coordinates': [-71.07764886, 42.36972686]}, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [{u'indices': [0, 8], u'text': u'hubspot'}], u'urls': [{u'url': u'https://t.co/a7nZ8muO6l', u'indices': [32, 55], u'expanded_url': u'https://www.instagram.com/p/BCbT0Uumeev3SwvYbKuEtkPewYQI0y5r26bkSc0/', u'display_url': u'instagram.com/p/BCbT0Uumeev3\u2026'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'704791263103463425', u'favorited': False, u'user': {u'follow_request_sent': None, u'has_extended_profile': True, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 10007922, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000048005209/fbce0e252278d51f7c23e8861e9bf810.png', u'verified': False, u'profile_text_color': u'3E4415', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000260430489/d866d00988ed0ae593a4ef2722f1805e_normal.jpeg', u'profile_sidebar_fill_color': u'99CC33', u'entities': {u'url': {u'urls': [{u'url': u'http://t.co/mzxQSpn9jf', u'indices': [0, 22], u'expanded_url': u'http://blog.hubspot.com/marketing/author/pamela-vaughan', u'display_url': u'blog.hubspot.com/marketing/auth\u2026'}]}, u'description': {u'urls': []}}, u'followers_count': 7348, u'profile_sidebar_border_color': u'FFFFFF', u'id_str': u'10007922', u'profile_background_color': u'F2852C', u'listed_count': 534, u'is_translation_enabled': False, u'utc_offset': -18000, u'statuses_count': 8760, u'description': u'Principal marketing manager of optimization at HubSpot. Can be found in stock photos on lots of random websites. Also the mother of two goofballs.', u'friends_count': 1757, u'location': u'Boston, MA', u'profile_link_color': u'487BC7', u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000260430489/d866d00988ed0ae593a4ef2722f1805e_normal.jpeg', u'following': None, u'geo_enabled': True, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/10007922/1401297448', u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000048005209/fbce0e252278d51f7c23e8861e9bf810.png', u'screen_name': u'pamelump', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 49, u'name': u'Pamela Vaughan', u'notifications': None, u'url': u'http://t.co/mzxQSpn9jf', u'created_at': u'Tue Nov 06 19:35:31 +0000 2007', u'contributors_enabled': False, u'time_zone': u'Eastern Time (US & Canada)', u'protected': False, u'default_profile': False, u'is_translator': False}, u'geo': {u'type': u'Point', u'coordinates': [42.36972686, -71.07764886]}, u'in_reply_to_user_id_str': None, u'possibly_sensitive': False, u'lang': u'en', u'created_at': u'Tue Mar 01 22:11:46 +0000 2016', u'in_reply_to_status_id_str': None, u'place': {u'country_code': u'US', u'url': u'https://api.twitter.com/1.1/geo/id/8193d87541f11dfb.json', u'country': u'United States', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-71.160356, 42.352429], [-71.064398, 42.352429], [-71.064398, 42.4039663], [-71.160356, 42.4039663]]]}, u'contained_within': [], u'full_name': u'Cambridge, MA', u'attributes': {}, u'id': u'8193d87541f11dfb', u'name': u'Cambridge'}, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}, {u'contributors': None, u'truncated': False, u'text': u'Garrison Brothers Cowboy Bourbon (TM) sighting! Cambridge, MA. #garrisonbros #drinktexasbourbon\u2026 https://t.co/gOt46HJVvj', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 704791108438532097L, u'favorite_count': 3, u'sou ...

# %%
""" Does pretty much what its long name suggests. """
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 60
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 30 
    while remaining_seconds > 0:
        added = 0
        # We hit the Twitter API
        new_tweets = get_tweets( latlong )
        # We parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets and tweet['coordinates'] != None:
                properties = {}
                properties['lat'] = tweet['coordinates']['coordinates'][1]
                properties['lon'] = tweet['coordinates']['coordinates'][0]
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['user_location'] = tweet['user']['location']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print "At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets ) )
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    # We return the final dictionary
    return all_tweets
print get_lots_of_tweets( latlong )
# Out:
# At 0 seconds, added 89 new tweets, for a total of 89
# At 30 seconds, added 1 new tweets, for a total of 90
797], [-70.986004, 42.227797], [-70.986004, 42.399542], [-71.191421, 42.399542]]]}, u'contained_within': [], u'full_name': u'Boston, MA', u'attributes': {}, u'id': u'67b98f17fdcf20be', u'name': u'Boston'}, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}, 'data_point': 'none', 'user_location': u'Somerville, MA', 'lon': -71.0968933, 'content': u"Another shot of @teacuphilosophy from last week's high key shoot. Have class tonight and handing\u2026 https://t.co/TpDSBh8Rjx", 'tweet_id': 704727584802803712L, 'user': 106192667, 'time': u'Tue Mar 01 17:58:44 +0000 2016', 'lat': 42.3491058}, 704760593647972 ...

# %%
'''This function executes the rest of the functions over a given period of time'''
def run():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            # We define a centroid in Riyadh
            latlong = [42.3598, -71.0921]
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/%stweets.json' %(timestr), 'w' ) as f:
                f.write( json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            #threading.Timer(10, run).start()
            starting -= 1
        except:
            pass
    
run()
# Out:
# At 0 seconds, added 89 new tweets, for a total of 89
# At 30 seconds, added 1 new tweets, for a total of 90

# %%
# Import additional libraries
from os import listdir
from os.path import isfile, join
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Get the file names from a given directory
file_dir = 'data' # Set this to where your JSON saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# Initialize some lists to store the points, and the ids of the tweets
ids = []
all_pts = []
# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file)
    # Open the JSON
    with open(full_dir) as f:
        data = f.read()
        # Load the JSON as a dict
        dict = json.loads(data)
        # Only add the unique tweets to the list
        if not isinstance(dict, list):
            for key, val in dict.iteritems():
                if key not in ids:
                    ids.append(key)
                    lat = val['lat']
                    lon = val['lon']
                    tweet_id2 = val['tweet_id']
                    all_pts.append([lat,lon,tweet_id2])
pts = np.array(all_pts)
pts
# Out:
# array([[  2.47282937e+01,   4.66378998e+01,   7.04201226e+17],
#        [  2.47296034e+01,   4.66349627e+01,   7.04184657e+17],
#        [  2.46997625e+01,   4.66916418e+01,   7.04183163e+17],
#        ...,
#        [  4.23533474e+01,  -7.10702570e+01,   7.04751117e+17],
#        [  4.23497158e+01,  -7.11038631e+01,   7.04793877e+17],
#        [  4.23544411e+01,  -7.10805761e+01,   7.04794240e+17]])

# %%
# Use a scatter plot to make a quick visualization of the data points
#plt.scatter(pts[:,0], pts[:,1])
x=pts[:,0]
y=pts[:,1]
a=y
plt.scatter(x, y, c=a, cmap=plt.cm.coolwarm, linewidths=0)

# %%
import csv

with open("mit_tweets.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(pts)
